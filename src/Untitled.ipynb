# %%
from kinecter import kinecter
import matplotlib.pyplot as plt

# %%
kinect = kinecter.kinect()
# Out:
# kinect Started

# %%
kinect.start()
A=kinect.getDepthFrames()
kinect.stop()
# Out:
# kinect Started
# kinect Stopped

# %%
plt.matshow(kinect.frames[8
                         ])

# %%
A
